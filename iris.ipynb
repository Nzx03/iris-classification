# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# It does not have any missing value.

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# won't be removing outliers

# %%
sns.boxplot(df['sepal_width'])
# Out:
# <Axes: ylabel='sepal_width'>

# %%
plt.hist(df['sepal_width'], bins=10, density=True, alpha=0.6, color='b')
plt.title('Histogram for sepal width')
plt.xlabel(df['sepal_width'])
plt.ylabel('Frequency')
plt.show()

# %%
from scipy.stats import skew
print(skew(df['sepal_width']))
# Out:
# 0.330702812773315

# %% [markdown]
# it is approximately symmetric
